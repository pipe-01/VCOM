# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv.imread('ex3-images/view4.jpg')
image = cv.cvtColor(image, cv.COLOR_BGR2RGB)  # convert from BGR to RGB
plt.figure(figsize=(10,10))
plt.subplot(121),plt.imshow(image)
plt.title('Markers Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
points = []

def mouse_click(event, x, y, flags, param):
    if event == cv.EVENT_LBUTTONDOWN:
        # Add the selected point to the list
        points.append((x, y))
        # Draw a small circle at the selected point
        cv.circle(image, (x, y), 3, (0, 0, 255), -1)

# %%
# Create a window to display the image and set the mouse callback function
cv.namedWindow('image')
cv.setMouseCallback('image', mouse_click)

# Display the image until the user presses a key
while True:
    cv.imshow('image', image)
    key = cv.waitKey(1) & 0xFF
    if key == ord('q'):
        cv.destroyAllWindows()
        break

print(points)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\FILIPE~1\AppData\Local\Temp/ipykernel_18104/3782811722.py in mouse_click(event, x, y, flags, param)
#       6         points.append((x, y))
#       7         # Draw a small circle at the selected point
# ----> 8         cv2.circle(image, (x, y), 3, (0, 0, 255), -1)
#
# NameError: name 'cv2' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\FILIPE~1\AppData\Local\Temp/ipykernel_18104/3782811722.py in mouse_click(event, x, y, flags, param)
#       6         points.append((x, y))
#       7         # Draw a small circle at the selected point
# ----> 8         cv2.circle(image, (x, y), 3, (0, 0, 255), -1)
#
# NameError: name 'cv2' is not defined
